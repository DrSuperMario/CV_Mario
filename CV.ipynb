# %%
import pandas as pd
import matplotlib.pyplot as plt
#matplotlib image module
import matplotlib.image as imgRead
import var.profileVariables as profile

# %%
#reading in the image
params = profile.ProfileStatic
img = imgRead.imread('ink.png')

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5)) #add two subplots with figsize
ax[0].imshow(img)
ax[1].pie(profile.ProfileStatic.NUMBERS.value, labels=profile.ProfileStatic.LANGUAGES.value,
          explode=profile.ProfileStatic.EXPLODEPARAM.value, shadow=True, autopct='%1.1f%%');

# %%
list(profile.ProfileStatic)

# %%
profile.ProfileStatic.EXPLODEPARAM.value
